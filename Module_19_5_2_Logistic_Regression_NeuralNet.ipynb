# %% [markdown]
# <a href="https://colab.research.google.com/github/AimeeJLewis/Nueral_Network_Charity_Analysis/blob/main/Module_19_5_2_Logistic_Regression_NeuralNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-58f3c3cb-5ba3-448e-a14e-336f5477d53e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58f3c3cb-5ba3-448e-a14e-336f5477d53e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes.csv to diabetes.csv

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 1s 5ms/step - loss: 0.7540 - accuracy: 0.5139
# Epoch 2/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6982 - accuracy: 0.6094
# Epoch 3/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6530 - accuracy: 0.6580
# Epoch 4/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6186 - accuracy: 0.6858
# Epoch 5/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.7031
# Epoch 6/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5701 - accuracy: 0.7240
# Epoch 7/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5533 - accuracy: 0.7222
# Epoch 8/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5386 - accuracy: 0.7448
# Epoch 9/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5273 - accuracy: 0.7622
# Epoch 10/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5173 - accuracy: 0.7569
# Epoch 11/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5089 - accuracy: 0.7639
# Epoch 12/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7708
# Epoch 13/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4956 - accuracy: 0.7708
# Epoch 14/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4898 - accuracy: 0.7743
# Epoch 15/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4845 - accuracy: 0.7778
# Epoch 16/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4804 - accuracy: 0.7795
# Epoch 17/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4762 - accuracy: 0.7830
# Epoch 18/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.7847
# Epoch 19/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4695 - accuracy: 0.7865
# Epoch 20/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4669 - accuracy: 0.7899
# Epoch 21/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.7899
# Epoch 22/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4617 - accuracy: 0.7899
# Epoch 23/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4597 - accuracy: 0.7865
# Epoch 24/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4576 - accuracy: 0.7899
# Epoch 25/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4561 - accuracy: 0.7865
# Epoch 26/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4541 - accuracy: 0.7865
# Epoch 27/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.7865
# Epoch 28/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4512 - accuracy: 0.7882
# Epoch 29/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4497 - accuracy: 0.7917
# Epoch 30/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4488 - accuracy: 0.7917
# Epoch 31/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4471 - accuracy: 0.7917
# Epoch 32/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4463 - accuracy: 0.7934
# Epoch 33/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4450 - accuracy: 0.7917
# Epoch 34/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4443 - accuracy: 0.7934
# Epoch 35/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.7934
# Epoch 36/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4422 - accuracy: 0.7969
# Epoch 37/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4410 - accuracy: 0.7969
# Epoch 38/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4402 - accuracy: 0.7934
# Epoch 39/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4391 - accuracy: 0.7934
# Epoch 40/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4380 - accuracy: 0.7951
# Epoch 41/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4373 - accuracy: 0.7986
# Epoch 42/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.7934
# Epoch 43/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4352 - accuracy: 0.7934
# Epoch 44/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4345 - accuracy: 0.7951
# Epoch 45/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4335 - accuracy: 0.7917
# Epoch 46/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4327 - accuracy: 0.7969
# Epoch 47/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.7951
# Epoch 48/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4313 - accuracy: 0.7951
# Epoch 49/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4307 - accuracy: 0.8003
# Epoch 50/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4295 - accuracy: 0.7986
# 6/6 - 0s - loss: 0.4707 - accuracy: 0.7448 - 150ms/epoch - 25ms/step
# Loss: 0.47070470452308655, Accuracy: 0.7447916865348816
